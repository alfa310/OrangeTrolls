# %%
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing
import json
import csv
# Paravisualizacion
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Usamos el API de twitter
def twitter_setup():
    with open("../../twitterKeys/json_credentials.json", "r") as file:  
        creds = json.load(file)
        # Autenticación y acceso
        auth = tweepy.OAuthHandler(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])
        auth.set_access_token(creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])

        #API con autenticación
        api = tweepy.API(auth)
        return api
    
def removeLinks(inputItem):
    lst=inputItem.split()
    outputLst=[]
    for item in lst:
        if "https" not in item:
            outputLst.append(item)
    return " ".join(outputLst)

def ignoreSomeCharacters(item):
    item=item.replace('\n', ' ')
    item=item.replace('…',' ')
    return item 

def createMinFile(inputCsv,outputFilename):
    with open(inputCsv, 'r') as f:
        reader = csv.reader(f)
        lst=[row[1] for row in list(reader)]
        with open(outputFilename, 'w') as file_handler:
            for item in lst[1:]:
                item=ignoreSomeCharacters(item)
                item=removeLinks(item)
                if len(item)>0:
                    file_handler.write("{}\n".format(item))

# %%
extractor = twitter_setup()

# %%
userLst=['DiarioDeCurwen','rmapalacios','sigridbazan','VertizPamela','litolobo','aleja_puente','hugonopo','larryportera','rodrigosp82','PCaterianoB','eloymarchan','aberron','duermalok','ocram','heduardo50','matuk','JoseLuisGil1000','JuanSheput','GGG_pe','jjgchau','LDavelouis','reformoagrario','joaquinreyh','GonzaloRamirezT','eljorobado','MijaelGLP','omarzev','augustoreyh','AlbertoBelaunde']

for user_name in userLst:
    print("user_name is "+user_name)
    tweets = extractor.user_timeline(id=user_name, count=200)
    print("Number of tweets extracted: {}.\n".format(len(tweets)))
    data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
    data.to_csv(user_name+'_full.csv')
    createMinFile(user_name+'_full.csv',user_name+'_min.csv')
# Out:
# user_name is DiarioDeCurwen
# Number of tweets extracted: 200.
#
# user_name is rmapalacios
# Number of tweets extracted: 200.
#
# user_name is sigridbazan
# Number of tweets extracted: 200.
#
# user_name is VertizPamela
# Number of tweets extracted: 199.
#
# user_name is litolobo
# Number of tweets extracted: 200.
#
# user_name is aleja_puente
# Number of tweets extracted: 200.
#
# user_name is hugonopo
# Number of tweets extracted: 200.
#
# user_name is larryportera
# Number of tweets extracted: 200.
#
# user_name is rodrigosp82
# Number of tweets extracted: 199.
#
# user_name is PCaterianoB
# Number of tweets extracted: 200.
#
# user_name is eloymarchan
# Number of tweets extracted: 200.
#
# user_name is aberron
# Number of tweets extracted: 200.
#
# user_name is duermalok
# Number of tweets extracted: 200.
#
# user_name is ocram
# Number of tweets extracted: 200.
#
# user_name is heduardo50
# Number of tweets extracted: 200.
#
# user_name is matuk
# Number of tweets extracted: 200.
#
# user_name is JoseLuisGil1000
# Number of tweets extracted: 200.
#
# user_name is JuanSheput
# Number of tweets extracted: 200.
#
# user_name is GGG_pe
# Number of tweets extracted: 200.
#
# user_name is jjgchau
# Number of tweets extracted: 200.
#
# user_name is LDavelouis
# Number of tweets extracted: 200.
#
# user_name is reformoagrario
# Number of tweets extracted: 200.
#
# user_name is joaquinreyh
# Number of tweets extracted: 200.
#
# user_name is GonzaloRamirezT
# Number of tweets extracted: 200.
#
# user_name is eljorobado
# Number of tweets extracted: 200.
#
# user_name is MijaelGLP
# Number of tweets extracted: 199.
#
# user_name is omarzev
# Number of tweets extracted: 198.
#
# user_name is augustoreyh
# Number of tweets extracted: 200.
#
# user_name is AlbertoBelaunde
# Number of tweets extracted: 200.
