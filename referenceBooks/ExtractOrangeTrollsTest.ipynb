# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# Paravisualizacion
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# CArga de credenciales Twitter

# %%
# Usamos el API de twitter
def twitter_setup():
    with open("../twitterKeys/json_credentials.json", "r") as file:  
        creds = json.load(file)
        # Autenticación y acceso
        auth = tweepy.OAuthHandler(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])
        auth.set_access_token(creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])

        #API con autenticación
        api = tweepy.API(auth)
        return api

# %%
# Se crea un extractor
extractor = twitter_setup()
# Se crea la lista de tweets a extraer
user_name="MEMEOPERU"
tweets = extractor.user_timeline(id=user_name, count=200)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# Impresion de 5 tweets, como ejemplo
print("5 ultimos tweets:\n")
for tweet in tweets[:5]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 200.
#
# 5 ultimos tweets:
#
# https://t.co/cxhUGPNkHc
#
# Fiscaloco y Gorriti terminan peor que zapatilla.
#
# La fiscalía, a través de su cuenta de Twitter, publicó un documen… https://t.co/UYzCJB9mPi
#
# Pero como es  rojo no le pasará nada.
#
# La Fiscalía anticorrupción de Junín prepara desde julio de este año la acusa… https://t.co/QD3Iqp8rBJ
#
# En medio de la audiencia del caso 'Los Temerarios del Crimen', realizada este viernes 14 de diciembre en la ciudad… https://t.co/u7j3iTKFIu
#
# Ahora sabemos porque este fiscal la hace más larga para traer a Toledo de USA. El sano y sagrado cuando le habrá pa… https://t.co/GWZHaDUHye

# %%
extractor.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '366294470-4PkcWhssaLnYpfYeHx06QVhf3m8gANv7Ad3V38zS'},
#  'resources': {'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1544897661}},
#   'account_activity': {'/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1544897661},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1544897661},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1544897661},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1544897661},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1544897661}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661}},
#   'blocks': {'/blocks/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/blocks/list': {'limit': 15, 'remaining': 15, 'reset': 1544897661}},
#   'business_experience': {'/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661}},
#   'collections': {'/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1544897661},
#    '/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1544897661},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1544897661}},
#   'contacts': {'/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1544897661},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1544897661},
#    '/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1544897661},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1544897661},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1544897661}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661}},
#   'direct_messages': {'/direct_messages': {'limit': 300,
#     'remaining': 300,
#     'reset': 1544897661},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1544897661},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1544897661},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1544897661},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1544897661},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1544897661},
#    '/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1544897661},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1544897661},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1544897661},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1544897661},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661}},
#   'drafts': {'/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1544897661}},
#   'feedback': {'/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1544897661},
#    '/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1544897661}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1544897661}},
#   'friendships': {'/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1544897661},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1544897661}},
#   'geo': {'/geo/id/:place_id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1544897661},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/geo/similar_places': {'limit': 15, 'remaining': 15, 'reset': 1544897661}},
#   'graphql&POST': {'/graphql&POST': {'limit': 2500,
#     'remaining': 2500,
#     'reset': 1544897661}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1544897661}},
#   'help': {'/help/configuration': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1544897661}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1544897661}},
#   'lists': {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1544897661},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1544897661},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1544897661},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1544897661},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1544897661},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/lists/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1544897661}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1544897661}},
#   'moments': {'/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1544897661},
#    '/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1544897661}},
#   'mutes': {'/mutes/users/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/mutes/users/list': {'limit': 15, 'remaining': 15, 'reset': 1544897661}},
#   'oauth': {'/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661}},
#   'safety': {'/safety/detection_feedback': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1544897661}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1544897661}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/saved_searches/list': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661}},
#   'statuses': {'/statuses/friends': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1544897661},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1544897661},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1544897661},
#    '/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1544897661},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1544897661},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1544897661},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1544897661},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 898,
#     'reset': 1544897539}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661}},
#   'trends': {'/trends/available': {'limit': 75,
#     'remaining': 75,
#     'reset': 1544897661},
#    '/trends/closest': {'limit': 75, 'remaining': 75, 'reset': 1544897661},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1544897661}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661}},
#   'tweets': {'/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1544897661},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1544897661},
#    '/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1544897661},
#    '/tweets/stream/filter/rules': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/tweets/stream/filter/rules/:instance_name&DELETE': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/tweets/stream/filter/rules/:instance_name&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/tweets/stream/filter/rules/:instance_name/:rule_id': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661},
#    '/tweets/stream/filter/rules/:instance_name/validation&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1544897661}},
#   'users': {'/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1544897661},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1544897661},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1544897661},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1544897661},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1544897661},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1544897661},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1544897661},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661}},
#   'webhooks': {'/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661},
#    '/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1544897661}}}}

# %%
# Se crea un dataframe:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# Se muestra 10 filas
display(data.head(10))
# Out:
#                                               Tweets
# 0                            https://t.co/cxhUGPNkHc
# 1  Fiscaloco y Gorriti terminan peor que zapatill...
# 2  Pero como es  rojo no le pasará nada.\n\nLa Fi...
# 3  En medio de la audiencia del caso 'Los Temerar...
# 4  Ahora sabemos porque este fiscal la hace más l...
# 5  Ahora  sabemos porque este fiscal la hace más ...
# 6  Según exalcalde de Chiclayo congresista Clemen...
# 7  Según exalcalde de Chiclayo congresista Clemen...
# 8  Alcalde saliente de Chiclayo, David Cornejo Ch...
# 9  Esta mañana Odebrecht es inhabilitada en Colom...

# %%
# Metodos internos en un tweet simple
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# Informacion de los tweets recolectados, del tweet0
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1073796775465623557
# 2018-12-15 04:27:56
# Facebook
# 1
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/cxhUGPNkHc', 'expanded_url': 'https://www.facebook.com/MEMEOPeru6/posts/528931904184605', 'display_url': 'facebook.com/MEMEOPeru6/pos…', 'indices': [0, 23]}]}

# %%
# Se añade columnas, para obtener un dataset basico
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

# %%
# Se muestra el dataset creado
display(data.head(10))
# Out:
#                                               Tweets  len  \
# 0                            https://t.co/cxhUGPNkHc   23
# 1  Fiscaloco y Gorriti terminan peor que zapatill...  140
# 2  Pero como es  rojo no le pasará nada.\n\nLa Fi...  140
# 3  En medio de la audiencia del caso 'Los Temerar...  139
# 4  Ahora sabemos porque este fiscal la hace más l...  140
# 5  Ahora  sabemos porque este fiscal la hace más ...  139
# 6  Según exalcalde de Chiclayo congresista Clemen...  140
# 7  Según exalcalde de Chiclayo congresista Clemen...  140
# 8  Alcalde saliente de Chiclayo, David Cornejo Ch...  139
# 9  Esta mañana Odebrecht es inhabilitada en Colom...  140
#
#                     ID                Date              Source  Likes  RTs
# 0  1073796775465623557 2018-12-15 04:27:56            Facebook      1    0
# 1  1073738761182343168 2018-12-15 00:37:24            Facebook     12    8
# 2  1073735258200305665 2018-12-15 00:23:29            Facebook     10    6
# 3  1073732927828254720 2018-12-15 00:14:13  Twitter Web Client     11    7
# 4  1073722345737633792 2018-12-14 23:32:10            Facebook     15   10
# 5  1073721953876361216 2018-12-14 23:30:37  Twitter Web Client     24   30
# 6  1073717331036127239 2018-12-14 23:12:15            Facebook     12    8
# 7  1073717009010044928 2018-12-14 23:10:58  Twitter Web Client      8   10
# 8  1073712774528798720 2018-12-14 22:54:08  Twitter Web Client    158  121
# 9  1073658362548641792 2018-12-14 19:17:55  Twitter Web Client     15   11

# %%
data.to_csv('MemeoPeruTest.csv')

# %%
data2 = data
#Creo un nuevo dataset para usarlos con tass
data2.columns.tolist()
dfFinal=data2[['ID','Tweets']]
#cambio de nombre las columnas
dfFinal.rename(columns={'ID':'tweetid','Tweets':'content'}, inplace=True)
dfFinal.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#                tweetid                                            content
# 0  1073796775465623557                            https://t.co/cxhUGPNkHc
# 1  1073738761182343168  Fiscaloco y Gorriti terminan peor que zapatill...
# 2  1073735258200305665  Pero como es  rojo no le pasará nada.\n\nLa Fi...
# 3  1073732927828254720  En medio de la audiencia del caso 'Los Temerar...
# 4  1073722345737633792  Ahora sabemos porque este fiscal la hace más l...

# %%
dfFinal.to_csv('MemeoPeruTest2.csv')  #guardo los resultados en un csv
